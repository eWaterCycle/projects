# %% [markdown]
# ## Startup

# %%
# General python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import numpy as np
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

# Niceties
from rich import print

from ipywidgets import IntProgress
from IPython.display import display
import shutil

# %%
# General eWaterCycle
import ewatercycle
import ewatercycle.models
import ewatercycle.forcing

# %%
# file_path = Path.home() / "BEP-maxime" / "book" / "thesis_projects" / "BSc" / "2026_Q4_MaximedeBekker_CEG" / "Workyard" / "forcings" / "CMIP6" / "ssp245" / "CMIP6-1000-1000"
file_path = Path.home() / "BEP-maxime" / "Workyard" / "forcings" / "CMIP6" / "historical" / "CMIP6-1995-1994" 
print(file_path.exists())

list(file_path.iterdir())[:10]
# Out:
# True
# [PosixPath('/home/maxime/BEP-maxime/Workyard/forcings/CMIP6/historical/CMIP6-1990-1994/run'),
#  PosixPath('/home/maxime/BEP-maxime/Workyard/forcings/CMIP6/historical/CMIP6-1990-1994/preproc'),
#  PosixPath('/home/maxime/BEP-maxime/Workyard/forcings/CMIP6/historical/CMIP6-1990-1994/work'),
#  PosixPath('/home/maxime/BEP-maxime/Workyard/forcings/CMIP6/historical/CMIP6-1990-1994/plots'),
#  PosixPath('/home/maxime/BEP-maxime/Workyard/forcings/CMIP6/historical/CMIP6-1990-1994/index.html')]

# %%
if file_path.exists() and file_path.is_dir():
    for item in file_path.iterdir():
        if item.is_dir():
            shutil.rmtree(item)
        else:
            item.unlink()
else:
    print("Folder does not exist or is not a folder.")
