# %% [markdown]
# # Results ERA5

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import matplotlib.pyplot as plt
from cartopy import crs
from cartopy import feature as cfeature
import fiona
import shapely.geometry
from pyproj import Geod
from rich import print
import pandas as pd
import xarray as xr

import ewatercycle.forcing
import ewatercycle.models
import ewatercycle.parameter_sets

# %% [markdown]
# ### 1990-2000

# %%
approx_9010 = pd.read_csv('approx2010_2020.csv')
discharge_9010 = pd.read_csv('discharge2010_2020.csv')
recharge_9010 = pd.read_csv('recharge2010_2020.csv')

# %% [markdown]
# ### 2000-2010

# %%
approx_1020 = pd.read_csv('approx2010_2020.csv')
discharge_1020 = pd.read_csv('discharge2010_2020.csv')
recharge_1020 = pd.read_csv('recharge2010_2020.csv')

# %% [markdown]
# ### 2010-2020

# %%
approx_1020 = pd.read_csv('approx2010_2020.csv')
discharge_1020 = pd.read_csv('discharge2010_2020.csv')
recharge_1020 = pd.read_csv('recharge2010_2020.csv')

# %%
discharge_1020['Discharge'] = discharge_1020.mean(axis=1) * 86400 * 1000 / (388.541*10**6)
discharge_1020['Discharge'].plot(title='Discharge (2010-2020)', ylabel='Discharge [mm/day]', color="darkblue")
# Out:
# <Axes: title={'center': 'Discharge (2010-2020)'}, ylabel='Discharge [mm/day]'>

# %%
approx_1020['Approximation Groundwater Recharge'] = approx1020.mean(axis=1)*1000 #- Q['Discharge']
approx_1020['Approximation Groundwater Recharge'].plot(title='Approximation Groundwater Recharge ERA5 (2010-2020)', ylabel = 'Recharge [mm/day]', color="darkblue")
# Out:
# <Axes: title={'center': 'Approximation Groundwater Recharge ERA5 (2010-2020)'}, ylabel='Recharge [mm/day]'>

# %%
recharge_1020['Groundwater Recharge'] = recharge_1020.mean(axis=1)*1000
recharge_1020['Groundwater Recharge'].plot(title='Groundwater Recharge PCRGlob-WB ERA5 (2010-2020)', ylabel = 'Recharge [mm/day]', color="darkblue")
# Out:
# <Axes: title={'center': 'Groundwater Recharge PCRGlob-WB ERA5 (2010-2020)'}, ylabel='Recharge [mm/day]'>
