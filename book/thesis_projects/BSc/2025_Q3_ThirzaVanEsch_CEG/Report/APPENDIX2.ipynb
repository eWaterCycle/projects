# %% [markdown]
# # Appendix II: AI Prompts

# %% [markdown]
# ![Schermafbeelding 2025-03-26 115850](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_115850.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 120245.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_120245.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 120349.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_120349.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 120413.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_120413.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 120501.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_120501.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 120523.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_120523.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 121543.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_121543.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 121634.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_121634.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 121826.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_121826.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 121904.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_121904.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 122037.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_122037.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 122216.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_122216.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 122430.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_122430.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 122839.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_122839.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 122923.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_122923.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 123253.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_123253.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 133857.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_133857.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 134114.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_134114.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 134136.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_134136.png)

# %% [markdown]
# ![Schermafbeelding 2025-03-26 134451.png](../EINDRAPPORT/ai_prompts/Schermafbeelding_2025-03-26_134451.png)
