# %% [markdown]
# # Appendix

# %% [markdown]
# _Achtergrond informatie over verschillende onderdelen dat niet goed in het rapport gezet kon worden._
#
# Voor de hoogtemetingen van het stuwmeer zijn metingen van DAHITI gebruikt. Deze metingen hebben grote gaten ertussen zitten. Aangezien model 2 dagelijkse metingen heeft en is gekalibreerd op basis van model 1 zijn dit ook de dagen waarover het gemiddelde is genomen om te vergelijken .In figuur 12 is weergegeven hoeveel tijd er tussen de metingen zat in dagen.

# %% [markdown]
# <figure>
#   <img src="Figuren/DAHITI_2.png" width="800">
#   <figcaption><b>Figuur 12:</b> Tijd tussen DAHITI hoogtemetingen van het Brokopondomeer
#   </figcaption>
# </figure>

# %% [markdown]
# Voor de verhouding tussen de hoogte en het volume van het stuwmeer is er gebruik gemaakt van een energierapport van Sterl et al. In dat rapport is er een rule curve gebruikt als versimpeling van de verhouding bij hoge waterstanden (Sterl et al., 2020). In het huidige rapport is er gebruik gemaakt van de meer accurate verhouding, de oranje lijn zichtbaar in figuur 13.

# %% [markdown]
# <figure>
#   <img src="Figuren/Hoogteverhouding_2.png" width="400">
#   <figcaption><b>Figuur 13:</b> Verhouding hoogte en volume Brokopondomeer.
#   </figcaption>
# </figure>
