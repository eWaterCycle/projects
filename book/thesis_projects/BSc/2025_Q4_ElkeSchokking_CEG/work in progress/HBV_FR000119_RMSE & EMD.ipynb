# %% [markdown]
# # Running HBV Model for FR000119

# %% [markdown]
# ## Importing Python modules

# %%
# !pip install "rich[jupyter]"
# !pip install "geopandas"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rich[jupyter] in /home/elke/.local/lib/python3.12/site-packages (14.0.0)
# Requirement already satisfied: ipywidgets<9,>=7.5.1 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from rich[jupyter]) (8.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/elke/.local/lib/python3.12/site-packages (from rich[jupyter]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from rich[jupyter]) (2.19.1)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]) (8.32.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]) (3.0.13)
# Requirement already satisfied: mdurl~=0.1 in /home/elke/.local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich[jupyter]) (0.1.2)
# Requirement already satisfied: decorator in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (3.0.50)
# Requirement already satisfied: stack_data in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]) (0.2.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /home/elke/.local/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/elke/.local/lib/python3.12/site-packages (from geopandas) (0.11.0)
# Requirement already satisfied: packaging in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)

# %%
# General python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import numpy as np
from pathlib import Path
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import xarray as xr

# Niceties
from rich import print

# General eWaterCycle
import ewatercycle
import ewatercycle.models
import ewatercycle.forcing
from ewatercycle.forcing import sources
from ewatercycle.models import HBV

# %% [markdown]
# ## Choose region and time period

# %%
# name of the catchment
basin_name = "FR000119"

# defining dates for calibration
experiment_start_date = "2013-11-26T00:00:00Z"
experiment_end_date = "2019-12-31T00:00:00Z"

# %%
#Define Catchment Area
shapefile_path = Path.home() / "BEP-Elke" / "book" / "thesis_projects" / "BSc" / "2025_Q4_ElkeSchokking_CEG" / "work in progress" / "ShapefilesFR000119" / "FR000119.shp"

# %%
#check
catchment = gpd.read_file(shapefile_path)
catchment = catchment.to_crs(epsg=3035)
catchment["area_km2"] = catchment.geometry.area / 1e6  
basin_area = catchment["area_km2"].sum()
catchment.plot()
# Out:
# <Axes: >

# %%
print(f"Basin area: {basin_area:.2f} km²")
# Out:
# Basin area: 48437.19 km²

# %%
# Location forcing files in home directory
forcing_path = Path.home() / "forcing" / "FR000119"/"ERA5"
forcing_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Generate ERA 5 forcing

# %%
# Option one: generate forcing:
#ERA5_forcing = sources["LumpedMakkinkForcing"].generate(
    #dataset="ERA5",
    #start_time=experiment_start_date,
    #end_time=experiment_end_date,
    #shape=shapefile_path,
#)

# Option two: Load generated (merged) data
forcing_dir = Path("/home/elke/BEP-Elke/book/thesis_projects/BSc/2025_Q4_ElkeSchokking_CEG/work in progress/esmvaltool_output/ewcrep5yvtlv4f_20250525_104347/work/diagnostic/script")
ERA5_forcing = sources["LumpedMakkinkForcing"].load(directory=forcing_dir)

# %% [markdown]
# ## Defining historical data from eStreams
# The original CSV file had some formatting and encoding issues—like strange quotation marks and all the data crammed into a single column—which made it impossible to load with the usual pandas.read_csv() method. To work around this, I used a custom parser to manually extract the dates and discharge values.

# %%
# Manually parse the file
dates = []
discharges = []

with open("A3550050.csv", "r", encoding="utf-8") as f:
    next(f)
    for line in f:
        parts = line.replace('""', '"').strip().split(',"')
        if len(parts) >= 2:
            date_str = parts[0].strip('"')
            discharge_str = parts[1].strip('"')
            try:
                dates.append(pd.to_datetime(date_str))
                discharges.append(float(discharge_str))
            except ValueError:
                continue

discharge_series = pd.Series(discharges, index=dates, name="Discharge (m³/s)")
Q_obs = discharge_series[experiment_start_date:experiment_end_date]

# %%
# Plot
Q_obs.plot(figsize=(12,4), title="Daily Discharge (m³/s), Observed")
plt.ylabel("Discharge (m³/s)")
plt.show()

# %% [markdown]
# ## Load parameters from calibration

# %%
# # Parameters supervisor
# par_0 = [7.0850, 0.8370, 76.373, 1.1120, 0.2450, 7.8010, 0.0960, 0.0030, 0.2260]
# param_names = ["Imax", "Ce", "Sumax", "Beta", "Pmax", "Tlag", "Kf", "Ks", "FM"]

# # Initial storages for HBV (in mm)
# # [Si, Su, Sf, Ss, Sp]
# s_0 = np.array([0, 100, 0, 5, 0])

# %%
# Calibrated parameters RMSE & EMD
par_0 = [5.2023, 0.7735, 514.3276, 2.1726, 0.1879, 6.8253, 0.017, 0.0099, 2.9328]
param_names = ['Imax', 'Ce', 'Sumax', 'Beta', 'Pmax', 'Tlag', 'Kf', 'Ks', 'FM']

#Calibrated parameters, logNSE & EMD
#par_0 = [4.533, 0.4272, 442.0109, 1.0321, 0.0714, 8.5025, 0.0139, 0.0099, 1.085]
#param_names = ['Imax', 'Ce', 'Sumax', 'Beta', 'Pmax', 'Tlag', 'Kf', 'Ks', 'FM']

# Initial storages for HBV (in mm)
# [Si, Su, Sf, Ss, Sp]
s_0 = np.array([0, 100, 0, 5, 0])

# %%
# Create HBV model instance with prepared ERA5 forcing
model = HBV(forcing=ERA5_forcing)

config_file, _ = model.setup(parameters=par_0, initial_storage=s_0)
model.initialize(config_file)

# %%
# Run the model
Q_m = []
time = []
while model.time < model.end_time:
    model.update()
    Q_m.append(model.get_value("Q")[0])
    time.append(pd.Timestamp(model.time_as_datetime))

model.finalize()

# %% [markdown]
# ## Show results

# %%
simulated_discharge = pd.Series(data=Q_m, index=time, name="Simulated Discharge")

# Plot mm/day
simulated_discharge.plot(figsize=(12, 4), title="HBV Simulated Discharge (mm/day)")
plt.ylabel("Discharge (mm/day)")
plt.xlabel("Date")
plt.grid()
plt.show()

# Convert HBV output (mm/day) to m³/s
def convert_to_m3s(Q_mmday, area_km2):
    return Q_mmday * area_km2 * 1e3 / 86400

# Convert simulated discharge
Q_sim_m3s = convert_to_m3s(simulated_discharge, basin_area)
Q_sim_m3s.name = "Simulated Discharge"

# Plot m³/s
Q_sim_m3s.plot(figsize=(12, 4), title="HBV Simulated Discharge (m³/s)")
plt.ylabel("Discharge (m³/s)")
plt.xlabel("Date")
plt.grid()
plt.show()

# %% [markdown]
# ## Observed VS Simulated

# %%
Q_obs_m3s = discharge_series.copy()
Q_obs_m3s.name = "Observed Discharge"

# Convert both indices to timezone
Q_sim_m3s.index = Q_sim_m3s.index.tz_localize(None)
Q_obs_m3s.index = Q_obs_m3s.index.tz_localize(None)

# Align
start = max(Q_sim_m3s.index.min(), Q_obs_m3s.index.min())
end = min(Q_sim_m3s.index.max(), Q_obs_m3s.index.max())

Q_sim_aligned = Q_sim_m3s[start:end]
Q_obs_aligned = Q_obs_m3s[start:end]

# %%
#Plot
plt.figure(figsize=(14, 6))
Q_obs_aligned.plot(label="Observed Discharge", color="red")
Q_sim_aligned.plot(label="Simulated Discharge", color="blue")
plt.title("Simulated vs Observed Discharge")
plt.ylabel("Discharge (m³/s)")
plt.xlabel("Time")

# Get current y-limits to create y ticks
ymin, ymax = plt.ylim()

# Define new ticks including 500
yticks = np.arange(0, ymax + 1, 500)
if 500 not in yticks:
    yticks = np.append(yticks, 500)
    yticks = np.sort(yticks)

# Set the ticks before showing the plot
plt.yticks(yticks)

plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Low flows

# %%
from critical_days_module import classify_discharge_status, get_segments_final_color_safe
# Out:
# Exported functions to: critical_days_module.py

# %%
def plot_classified_discharge_pair(obs_series, sim_series, year, threshold=500):
    fig, axes = plt.subplots(2, 1, figsize=(14, 8), sharex=True)

    for ax, data, label in zip(
        axes,
        [obs_series[str(year)], sim_series[str(year)]],
        ["Observed", "Simulated"]
    ):
        values = data.values
        days = list(range(1, len(values) + 1))

        statuses = classify_discharge_status(values)
        segments, colors = get_segments_final_color_safe(days, values, threshold)

        for (x_seg, y_seg), color in zip(segments, colors):
            ax.plot(x_seg, y_seg, color=color, linewidth=2.5)

        ax.axhline(threshold, color='blue', linestyle='--', label='Threshold (500 m³/s)')
        ax.set_ylabel("Discharge [m³/s]")
        ax.set_title(f"{label} Discharge - {year}")
        ax.grid(True)

    # Legenda op onderste subplot
    axes[-1].plot([], [], color='yellow', label='Caution (1–3d)')
    axes[-1].plot([], [], color='orange', label='Risk (4–7d)')
    axes[-1].plot([], [], color='red', label='Critical (>7d)')
    axes[-1].plot([], [], color='black', label='Normal')
    axes[-1].legend()
    axes[-1].set_xlabel("Day of Year")

    plt.tight_layout()
    plt.show()

# %%
for year in [2016, 2017, 2018]:
    plot_classified_discharge_pair(Q_obs_aligned, Q_sim_aligned, year)

# %% [markdown]
# ## Check drought analyser

# %%
from critical_days_module import droughts

# %%
Q_sim = Q_sim_m3s[start:end] #Convert Q_m to a time-indexed series (same length as Q_obs):

# %%
obs_droughts = droughts(Q_obs, basin_name="FR000119", q_crit=500)
sim_droughts = droughts(Q_sim, basin_name="FR000119", q_crit=500)

# %%
print("Observed droughts:")
display(obs_droughts.head())

print("Simulated droughts:")
display(sim_droughts.head())
# Out:
# Observed droughts:
#    Drought Number                Start Date  Duration (days)  \
# 0               1 2016-12-29 00:00:00+00:00                1
# 1               2 2016-12-31 00:00:00+00:00                3
# 2               3 2017-01-05 00:00:00+00:00                7
# 3               4 2017-01-22 00:00:00+00:00                2
# 4               5 2017-01-28 00:00:00+00:00                3
#
#    Max Cumulative Deficit (m3/s)  \
# 0                          -17.0
# 1                          -50.0
# 2                         -125.0
# 3                          -32.0
# 4                          -47.0
#
#                                     Cum Deficit List     Basin
# 0                                            [-17.0]  FR000119
# 1                              [-20.0, -42.0, -50.0]  FR000119
# 2  [-27.0, -52.0, -68.0, -83.0, -112.0, -121.0, -...  FR000119
# 3                                     [-16.0, -32.0]  FR000119
# 4                               [-7.0, -28.0, -47.0]  FR000119
# Simulated droughts:
#    Drought Number          Start Date  Duration (days)  \
# 0               1 2017-01-13 12:00:00               22
# 1               2 2018-10-27 12:00:00                3
# 2               3 2018-11-26 12:00:00                8
#
#    Max Cumulative Deficit (m3/s)  \
# 0                    -830.565600
# 1                     -10.593158
# 2                     -19.154948
#
#                                     Cum Deficit List     Basin
# 0  [-3.5748921646354574, -9.583578950227945, -14....  FR000119
# 1  [-2.465122583849279, -8.144015602977845, -10.5...  FR000119
# 2  [-1.7079766451306, -4.435361894420055, -7.1529...  FR000119
