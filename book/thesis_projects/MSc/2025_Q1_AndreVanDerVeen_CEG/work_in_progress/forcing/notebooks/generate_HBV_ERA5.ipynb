# %% [markdown]
# ## Generate ERA5 forcing for HBV etc

# %%
# setup imports
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[1]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

from src.forcing import setup_ERA5_forcing
from src.paths import *

# %%
experiment_start_date = "1959-01-01T00:00:00Z"
experiment_end_date = "1963-12-31T00:00:00Z"

shapefile_name = "Kerki_GRDC"

ERA5_forcing = setup_ERA5_forcing(shapefile_name, experiment_start_date, experiment_end_date)
