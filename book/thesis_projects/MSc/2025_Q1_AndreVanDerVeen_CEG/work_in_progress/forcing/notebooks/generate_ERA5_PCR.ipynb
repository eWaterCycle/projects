# %% [markdown]
# ## Generate forcing for PCR globwat

# %%
# setup imports
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[1]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

import warnings

from src.forcing import setup_ERA5_PCR_forcing
from src.paths import *

warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498

# %%
# experiment_start_date_1 = "1940-01-01T00:00:00Z"
# experiment_end_date_1 = "1960-12-31T00:00:00Z"
# PCR_Forcing_1 = setup_ERA5_PCR_forcing("AralSea_basin", experiment_start_date_1, experiment_end_date_1)

# %%
# experiment_start_date_2 = "1955-01-01T00:00:00Z"
# experiment_end_date_2 = "1980-12-31T00:00:00Z"
# PCR_Forcing_2 = setup_ERA5_PCR_forcing("AralSea_basin", experiment_start_date_2, experiment_end_date_2)

# %%
# experiment_start_date_3 = "1975-01-01T00:00:00Z"
# experiment_end_date_3 = "2000-12-31T00:00:00Z"
# PCR_Forcing_3 = setup_ERA5_PCR_forcing("AralSea_basin", experiment_start_date_3, experiment_end_date_3)

# %%
# experiment_start_date_4 = "1995-01-01T00:00:00Z"
# experiment_end_date_4 = "2020-12-31T00:00:00Z"
# PCR_Forcing_4 = setup_ERA5_PCR_forcing("AralSea_basin", experiment_start_date_4, experiment_end_date_4)

# %%
full_experiment_start_date = "1940-01-01T00:00:00Z"
full_experiment_end_date = "2020-12-31T00:00:00Z"
PCR_Forcing_full = setup_ERA5_PCR_forcing("AralSea_basin", full_experiment_start_date, full_experiment_end_date)
