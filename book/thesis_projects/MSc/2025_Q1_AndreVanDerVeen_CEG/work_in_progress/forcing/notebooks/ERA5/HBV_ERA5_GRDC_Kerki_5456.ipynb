# %% [markdown]
# # ERA5 Data Aral Sea - HBV Kerki
#
# runtime: 2 minutes

# %%
# General python
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

from pathlib import Path

# General eWaterCycle
import ewatercycle
import ewatercycle.forcing
import ewatercycle.models
import matplotlib.pyplot as plt
import xarray as xr

# Niceties
from rich import print

# %%
# The name of the shapefile
shape_file_name = "GRDC_Kerki"  # river: Bedford Ouse at Roxton, England

# The time-window of the experiment
experiment_start_date = "1954-01-01T00:00:00Z"
experiment_end_date = "1956-12-31T00:00:00Z"

forcing_path_ERA5 = (
    Path.cwd()
    / ".."
    / ".."
    / "Output"
    / "forcing_HBV_ERA5_GRDC_Kerki_5456"
    / shape_file_name
    / "ERA5"
    / "own_shapefile"
)

# The path save directory of the ERA5 data
# forcing_path_ERA5 = Path.home() / "projects/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Aral_Test/forcing" / shape_file_name / "ERA5" / "own_shapefile"
# forcing_path_ERA5.mkdir(exist_ok=True)
forcing_path_ERA5.mkdir(parents=True, exist_ok=True)

# %%
Path.cwd()
# Out:
# PosixPath('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Forcing/Notebooks')

# %%
shapefile_path = (
    Path(
        "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Test_Aral/AralSea_Basin/GRDC_Kerki"
    )
    / f"{shape_file_name}.shp"
)

# %%
ERA5_forcing = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
    dataset="ERA5",
    start_time=experiment_start_date,
    end_time=experiment_end_date,
    shape=shapefile_path,
    directory=forcing_path_ERA5,
)

# %%
print(ERA5_forcing)
# Out:
# LumpedMakkinkForcing(
#     start_time='1954-01-01T00:00:00Z',
#     end_time='1956-12-31T00:00:00Z',
#     directory=PosixPath('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in
# _progress/Forcing/Output/forcing_HBV_ERA5_GRDC_Kerki_5456/GRDC_Kerki/ERA5/own_shapefile/work/diagnostic/script'),
#     shape=PosixPath('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_pro
# gress/Test_Aral/AralSea_Basin/GRDC_Kerki/GRDC_Kerki.shp'),
#     filenames={
#         'pr': 'OBS6_ERA5_reanaly_1_day_pr_1954-1956.nc',
#         'tas': 'OBS6_ERA5_reanaly_1_day_tas_1954-1956.nc',
#         'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_1954-1956.nc',
#         'evspsblpot': 'Derived_Makkink_evspsblpot.nc'
#     }
# )

# %%
ERA5_data = {
    "precipitation pr": xr.open_dataset(ERA5_forcing["pr"]),
    "temperature tas": xr.open_dataset(ERA5_forcing["tas"]),
    "incoming_shortwave_radiation rsds": xr.open_dataset(ERA5_forcing["rsds"]),
    "potential_evaporation evspsblpot": xr.open_dataset(ERA5_forcing["evspsblpot"]),
}

plot_counter = 1
plt.figure(figsize=(15, 10))
for name, data in ERA5_data.items():
    plt.subplot(2, 2, plot_counter)
    data[name.split(" ")[-1]].plot()
    plt.title(f"{name.split(" ")[0]}")
    plot_counter += 1

plt.suptitle("ERA5 LumpedMakkink Data", fontsize=20)
plt.tight_layout()
