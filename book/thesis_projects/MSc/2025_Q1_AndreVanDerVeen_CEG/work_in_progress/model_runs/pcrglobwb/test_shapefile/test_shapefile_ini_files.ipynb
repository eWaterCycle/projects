# %% [markdown]
# ## testing ini files

# %%
# setup imports
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[2]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

from src.paths import INI_FILES
from src.utils import compare_inis

# %%
ini1 = Path(INI_FILES / "aral_basin_ad_sd_rivers_edge_05min_clone_mask.ini")
ini2 = Path(INI_FILES / "setup_05min_test_Kazalinsk_shp.ini")

# %%
compare_inis(ini1, ini2)
