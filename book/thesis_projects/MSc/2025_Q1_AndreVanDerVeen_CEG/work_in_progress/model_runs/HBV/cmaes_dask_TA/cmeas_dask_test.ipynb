# %% [markdown]
# # Testing with Dask
#
# Tyumen Arayk for model testing

# %%
# setup imports
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

PROJECT_ROOT = Path().resolve().parents[2]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

# %%
import warnings

import seaborn as sns
from dask import delayed
from dask.distributed import Client, progress
from ewatercycle.observation.grdc import get_grdc_data

from src.forcing import load_lumped_forcing_data
from src.models import *
from src.paths import *

warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498

# %%
shape_name = "Tyumen_Aryk_GRDC"
start_date = "1955-01-02T00:00Z"
end_date = "1959-12-31T00:00Z"


# forcing = generate_lumped_ERA5_forcing(shape_name, start=start_date,end=end_date)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py", line 816, in _run_task
#     output_files = task.run()
#                    ^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py", line 264, in run
#     self.output_files = self._run(input_files)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py", line 595, in _run
#     raise DiagnosticError(
# esmvalcore._task.DiagnosticError: Diagnostic script /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/esmvaltool/diagnostic/copier.py failed with return code 1. See the log in /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/forcing/output/ERA5/Tyumen_Aryk_GRDC/1955-1959/run/diagnostic/script/log.txt
# """
#
# The above exception was the direct cause of the following exception:
#
# DiagnosticError                           Traceback (most recent call last)
# Cell In[3], line 6
#       2 start_date = '1955-01-02T00:00Z'
#       3 end_date = '1959-12-31T00:00Z'
# ----> 6 forcing = generate_lumped_ERA5_forcing(shape_name, start=start_date,end=end_date)
#
# File ~/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/forcing.py:72, in generate_lumped_ERA5_forcing(shape_name, start, end)
#      69 forcing_dir.mkdir(parents=True, exist_ok=True)
#      71 # Generate forcing using eWaterCycle
# ---> 72 forcing = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
#      73     dataset="ERA5",
#      74     start_time=start,
#      75     end_time=end,
#      76     shape=shapefile,
#      77     directory=forcing_dir
#      78 )
#      80 return forcing
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/_forcings/makkink.py:57, in Makkink.generate(cls, dataset, start_time, end_time, shape, directory, **model_specific_options)
#      47 @classmethod
#      48 def generate(  # type: ignore[override]
#      49     cls: type["Makkink"],
#    (...)
#      55     **model_specific_options,
#      56 ) -> "Makkink":
# ---> 57     return super().generate(
#      58         dataset,
#      59         start_time,
#      60         end_time,
#      61         shape,
#      62         directory,
#      63         variables=("pr", "tas", "rsds"),
#      64         postprocessor=derive_e_pot,
#      65         **model_specific_options,
#      66     )
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/forcing.py:162, in DefaultForcing.generate(cls, dataset, start_time, end_time, shape, directory, variables, postprocessor, **model_specific_options)
#     129 """Generate forcings for a model.
#     130
#     131 The forcing is generated with help of
#    (...)
#     151     model_specific_options: Subclass specific options.
#     152 """
#     153 recipe = cls._build_recipe(
#     154     dataset=dataset,
#     155     start_time=get_time(start_time),
#    (...)
#     159     **model_specific_options,
#     160 )
# --> 162 recipe_output = cls._run_recipe(
#     163     recipe, directory=Path(directory) if directory else None
#     164 )
#     166 derived_variables: tuple[str, ...] = ()
#     167 if postprocessor is not None:
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/forcing.py:217, in DefaultForcing._run_recipe(cls, recipe, directory)
#     211 @classmethod
#     212 def _run_recipe(
#     213     cls,
#     214     recipe: Recipe,
#     215     directory: Path | None = None,
#     216 ) -> dict[str, str]:
# --> 217     return run_recipe(recipe, directory)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/esmvaltool/run.py:109, in run_recipe(recipe, output_dir)
#     100 warnings.filterwarnings(  # Not relevant for end users.
#     101     action="ignore",
#     102     message="Thank you for trying out the new ESMValCore API",
#     103 )
#     104 warnings.filterwarnings(  # Hide Iris warning (upstream issue)
#     105     action="ignore",
#     106     message="Saving to netcdf with legacy-style attribute",
#     107 )
# --> 109 output = _save_and_run_recipe(recipe, output_dir)
#     110 return _parse_recipe_output(output)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/esmvaltool/run.py:137, in _save_and_run_recipe(recipe, output_dir)
#     135     esmlvaltool_recipe = ESMValToolRecipe(recipe_path)
#     136     session = _session(output_dir)
# --> 137     output = esmlvaltool_recipe.run(session=session)
#     138 finally:
#     139     recipe_path.unlink()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/recipe.py:138, in Recipe.run(self, task, session)
#     136     _dask.check_distributed_config()
#     137     self._engine = self._load(session=session)
# --> 138     self._engine.run()
#     140 shutil.copy2(self.path, session.run_dir)
#     142 output = self.get_output()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:1095, in Recipe.run(self)
#    1092 if self.session['search_esgf'] != 'never':
#    1093     esgf.download(self._download_files, self.session['download_dir'])
# -> 1095 self.tasks.run(max_parallel_tasks=self.session['max_parallel_tasks'])
#    1096 logger.info(
#    1097     "Wrote recipe with version numbers and wildcards "
#    1098     "to:\nfile://%s", filled_recipe)
#    1099 self.write_html_summary()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py:738, in TaskSet.run(self, max_parallel_tasks)
#     736     self._run_sequential()
#     737 else:
# --> 738     self._run_parallel(address, max_parallel_tasks)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py:782, in TaskSet._run_parallel(self, scheduler_address, max_parallel_tasks)
#     780 ready = {t for t in running if running[t].ready()}
#     781 for task in ready:
# --> 782     _copy_results(task, running[task])
#     783     running.pop(task)
#     785 # Wait if there are still tasks running
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py:805, in _copy_results(task, future)
#     803 def _copy_results(task, future):
#     804     """Update task with the results from the remote process."""
# --> 805     task.output_files, task.products = future.get()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# DiagnosticError: Diagnostic script /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/esmvaltool/diagnostic/copier.py failed with return code 1. See the log in /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/forcing/output/ERA5/Tyumen_Aryk_GRDC/1955-1959/run/diagnostic/script/log.txt

# %%
ERA5_forcing_loaded = load_lumped_forcing_data("Tyumen_Aryk_GRDC", "ERA5", "1955-1959")


grdc_station = get_grdc_data(
    2316200, "1955-01-02T00:00Z", "1959-12-31T00:00Z", data_home=GRDC / "Daily"
)


q_obs = grdc_station["streamflow"]
years = q_obs["time"].dt.year.values

# %%
# CMA-ES test setup
x0_norm = scale(0.5 * (p_min + p_max))  # start in the middle
sigma0 = 0.1  # step size in normalized space

# Define 20 unique seeds
seeds = [
    180988,
    214025,
    987654,
    123456,
    654321,
    111222,
    333444,
    555666,
    777888,
    999000,
    112233,
    445566,
    778899,
    101010,
    202020,
    303030,
    404040,
    505050,
    606060,
    707070,
]

# results = []

# for s in seeds:
#     res = run_cma(
#         seed=s,
#         x0_norm=x0_norm,
#         sigma0=sigma0,
#         objective_fn=objective_safe,
#         popsize=18,
#         maxfevals=360,
#         save_path=f"results/result_seed_{s}.pkl",
#     )
#     results.append(res)

# %%
# Create a Dask client with 3 workers, 1 thread each, dashboard auto-assigned
client = Client(n_workers=3, threads_per_worker=1, dashboard_address=":0")

# Display client info (clickable dashboard link appears in Jupyter)
client
# Out:
# <Client: 'tcp://127.0.0.1:38315' processes=3 threads=3, memory=31.34 GiB>
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3784' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3779' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3787' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3783' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3780' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3789' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3785' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3782' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3788' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3786' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3781' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-3790' coro=<Client._gather.<locals>.wait() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2395> exception=AllExit()>
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py", line 2404, in wait
#     raise AllExit()
# distributed.client.AllExit

# %%
# client = Client()
# futures = client.futures  # all submitted tasks

# # Print active, pending, finished
# for f in futures:
#     print(f.key, f.status)

# %%
# from dask.distributed import Client

# # Assuming you created a client earlier
# client.close()  # closes client and shuts down local cluster/workers

# %%
# from dask.distributed import Client, default_client
# import warnings

# def close_dask():
#     try:
#         # Try to get the current default client
#         client = default_client()
#         print(f"Closing existing Dask client with {len(client.scheduler_info()['workers'])} workers...")
#         client.close()
#         print("Dask client closed successfully.")
#     except ValueError:
#         # No active client
#         print("No active Dask client found.")
#     except Exception as e:
#         warnings.warn(f"Error closing Dask client: {e}")

# # Run the cleanup
# close_dask()

# %%
# from dask import delayed, compute

# objective_fn = make_objective_safe(ERA5_forcing_loaded, q_obs.values, shape_name)
# number_runs = 10
# test_seeds = seeds[:number_runs]

# tasks = [delayed(run_cma)(
#     seed=s,
#     x0_norm=x0_norm,
#     sigma0=sigma0,
#     objective_fn=objective_fn,
#     popsize=10,
#     maxfevals=40,
#     save_folder="results_2/"
# ) for s in test_seeds]

# results = compute(*tasks)
# #print(results)

# %%
objective_fn = make_objective_safe(ERA5_forcing_loaded, q_obs.values, shape_name)
number_runs = 12
test_seeds = seeds[:number_runs]

tasks = [
    delayed(run_cma)(
        cma_seed=s,
        x0_norm=x0_norm,
        sigma0=sigma0,
        objective_fn=objective_fn,
        popsize=16,
        maxfevals=240,
        save_folder="results_7/",
    )
    for s in test_seeds
]

# Submit tasks to the cluster
futures = client.compute(tasks)

# Optional: see a live progress bar
progress(futures)

# Gather results when done
results = client.gather(futures)
# Out:
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498
# (8_w,16)-aCMA-ES (mu_w=4.8,w_1=32%) in dimension 9 (seed=777888, Mon Feb  2 15:37:29 2026)
# (8_w,16)-aCMA-ES (mu_w=4.8,w_1=32%) in dimension 9 (seed=445566, Mon Feb  2 15:37:29 2026)
# (8_w,16)-aCMA-ES (mu_w=4.8,w_1=32%) in dimension 9 (seed=123456, Mon Feb  2 15:37:29 2026)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     16 6.561371698594007e-01 1.0e+00 9.50e-02  9e-02  1e-01 2:08.5
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     16 6.814066624443823e-01 1.0e+00 1.06e-01  1e-01  1e-01 2:10.5
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     16 6.561371698594007e-01 1.0e+00 1.03e-01  1e-01  1e-01 2:14.3
# 2026-02-02 15:39:59,824 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('run_cma_single-fac9e636-79c5-432b-b660-b7b5c7d8348b')" coro=<Worker.execute() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2026-02-02 15:39:59,825 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('run_cma_single-ec92ea44-8698-4eee-a2be-8bd40e7fe252')" coro=<Worker.execute() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2026-02-02 15:39:59,828 - distributed.worker.state_machine - WARNING - Async instruction for <Task cancelled name="execute('run_cma_single-f7a33191-df74-4bdf-8d19-8bb55a7f392c')" coro=<Worker.execute() done, defined at /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/worker_state_machine.py:3606>> ended with CancelledError
# 2026-02-02 15:39:59,923 - distributed.protocol.pickle - ERROR - Failed to serialize <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "recvmsg:Connection reset by peer"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2026-02-02T15:39:59.921623623+01:00", grpc_status:14, grpc_message:"recvmsg:Connection reset by peer"}"
# >.
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/worker.py", line 2982, in _run_task_simple
#     result = task(data)
#              ^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/dask/_task_spec.py", line 651, in __call__
#     return self.func(*new_argspec)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/dask/utils.py", line 77, in apply
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 755, in run_cma_single
#     es.optimize(objective_wrapped)
#   File "/home/avandervee3/.local/lib/python3.12/site-packages/cma/interfaces.py", line 208, in optimize
#     fitvals = eval_all(X, args=args)
#               ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/.local/lib/python3.12/site-packages/cma/optimization_tools.py", line 285, in __call__
#     return [fitness_function(x, *args) for x in solutions]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 742, in objective_wrapped
#     return objective_fn(theta_norm, local_history)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 798, in objective
#     return objective_safe(theta_norm, forcing, q_obs, shape_name, history)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 564, in objective_HBV_safe
#     sim = run_hbv_single(theta_phys, forcing, shape_name)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 441, in run_hbv_single
#     model_output   = run_HBV_model(
#                      ^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 63, in simulate_HBV
#     Q_m.append(model.get_value("Q")[0])
#                ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/model.py", line 190, in get_value
#     return self._bmi.get_value(name)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_optionaldest.py", line 111, in get_value
#     return self.origin.get_value(name, dest)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_memoized.py", line 117, in get_value
#     return self.origin.get_value(var_name, dest)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py", line 239, in get_value
#     handle_error(e)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py", line 235, in get_value
#     response = self.stub.getValue(bmi_pb2.GetVarRequest(name=name))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py", line 1176, in __call__
#     return _end_unary_response_blocking(state, call, False, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py", line 1005, in _end_unary_response_blocking
#     raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# grpc._channel._InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "recvmsg:Connection reset by peer"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2026-02-02T15:39:59.921623623+01:00", grpc_status:14, grpc_message:"recvmsg:Connection reset by peer"}"
# >
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 60, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: cannot pickle '_thread.RLock' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 65, in dumps
#     pickler.dump(x)
# TypeError: cannot pickle '_thread.RLock' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 77, in dumps
#     result = cloudpickle.dumps(x, **dump_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/cloudpickle/cloudpickle.py", line 1529, in dumps
#     cp.dump(obj)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/cloudpickle/cloudpickle.py", line 1295, in dump
#     return super().dump(obj)
#            ^^^^^^^^^^^^^^^^^
# TypeError: cannot pickle '_thread.RLock' object
# 2026-02-02 15:39:59,996 - distributed.protocol.pickle - ERROR - Failed to serialize <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "recvmsg:Connection reset by peer"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"recvmsg:Connection reset by peer", grpc_status:14, created_time:"2026-02-02T15:39:59.99522797+01:00"}"
# >.
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/worker.py", line 2982, in _run_task_simple
#     result = task(data)
#              ^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/dask/_task_spec.py", line 651, in __call__
#     return self.func(*new_argspec)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/dask/utils.py", line 77, in apply
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 755, in run_cma_single
#     es.optimize(objective_wrapped)
#   File "/home/avandervee3/.local/lib/python3.12/site-packages/cma/interfaces.py", line 208, in optimize
#     fitvals = eval_all(X, args=args)
#               ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/.local/lib/python3.12/site-packages/cma/optimization_tools.py", line 285, in __call__
#     return [fitness_function(x, *args) for x in solutions]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 742, in objective_wrapped
#     return objective_fn(theta_norm, local_history)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 798, in objective
#     return objective_safe(theta_norm, forcing, q_obs, shape_name, history)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 564, in objective_HBV_safe
#     sim = run_hbv_single(theta_phys, forcing, shape_name)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 441, in run_hbv_single
#     model_output   = run_HBV_model(
#                      ^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 61, in simulate_HBV
#     while model.time < model.end_time:
#           ^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/model.py", line 312, in time
#     return self._bmi.get_current_time()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_optionaldest.py", line 79, in get_current_time
#     return self.origin.get_current_time()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_memoized.py", line 87, in get_current_time
#     return self.origin.get_current_time()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py", line 168, in get_current_time
#     handle_error(e)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py", line 166, in get_current_time
#     return self.stub.getCurrentTime(bmi_pb2.Empty()).time
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py", line 1176, in __call__
#     return _end_unary_response_blocking(state, call, False, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py", line 1005, in _end_unary_response_blocking
#     raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# grpc._channel._InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "recvmsg:Connection reset by peer"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"recvmsg:Connection reset by peer", grpc_status:14, created_time:"2026-02-02T15:39:59.99522797+01:00"}"
# >
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 60, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: cannot pickle '_thread.RLock' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 65, in dumps
#     pickler.dump(x)
# TypeError: cannot pickle '_thread.RLock' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 77, in dumps
#     result = cloudpickle.dumps(x, **dump_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/cloudpickle/cloudpickle.py", line 1529, in dumps
#     cp.dump(obj)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/cloudpickle/cloudpickle.py", line 1295, in dump
#     return super().dump(obj)
#            ^^^^^^^^^^^^^^^^^
# TypeError: cannot pickle '_thread.RLock' object
# 2026-02-02 15:40:00,013 - distributed.protocol.pickle - ERROR - Failed to serialize <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "recvmsg:Connection reset by peer"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"recvmsg:Connection reset by peer", grpc_status:14, created_time:"2026-02-02T15:40:00.011930375+01:00"}"
# >.
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/worker.py", line 2982, in _run_task_simple
#     result = task(data)
#              ^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/dask/_task_spec.py", line 651, in __call__
#     return self.func(*new_argspec)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/dask/utils.py", line 77, in apply
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 755, in run_cma_single
#     es.optimize(objective_wrapped)
#   File "/home/avandervee3/.local/lib/python3.12/site-packages/cma/interfaces.py", line 208, in optimize
#     fitvals = eval_all(X, args=args)
#               ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/.local/lib/python3.12/site-packages/cma/optimization_tools.py", line 285, in __call__
#     return [fitness_function(x, *args) for x in solutions]
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 742, in objective_wrapped
#     return objective_fn(theta_norm, local_history)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 798, in objective
#     return objective_safe(theta_norm, forcing, q_obs, shape_name, history)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 564, in objective_HBV_safe
#     sim = run_hbv_single(theta_phys, forcing, shape_name)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 441, in run_hbv_single
#     model_output   = run_HBV_model(
#                      ^^^^^^^^^^^^^^
#   File "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py", line 62, in simulate_HBV
#     model.update()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/model.py", line 182, in update
#     self._bmi.update()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_optionaldest.py", line 52, in update
#     self.origin.update()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_memoized.py", line 60, in update
#     self.origin.update()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py", line 107, in update
#     handle_error(e)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py", line 105, in update
#     self.stub.update(bmi_pb2.Empty())
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py", line 1176, in __call__
#     return _end_unary_response_blocking(state, call, False, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py", line 1005, in _end_unary_response_blocking
#     raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# grpc._channel._InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "recvmsg:Connection reset by peer"
# 	debug_error_string = "UNKNOWN:Error received from peer  {grpc_message:"recvmsg:Connection reset by peer", grpc_status:14, created_time:"2026-02-02T15:40:00.011930375+01:00"}"
# >
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 60, in dumps
#     result = pickle.dumps(x, **dump_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: cannot pickle '_thread.RLock' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 65, in dumps
#     pickler.dump(x)
# TypeError: cannot pickle '_thread.RLock' object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/protocol/pickle.py", line 77, in dumps
#     result = cloudpickle.dumps(x, **dump_kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/cloudpickle/cloudpickle.py", line 1529, in dumps
#     cp.dump(obj)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/cloudpickle/cloudpickle.py", line 1295, in dump
#     return super().dump(obj)
#            ^^^^^^^^^^^^^^^^^
# TypeError: cannot pickle '_thread.RLock' object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 27
#      24 progress(futures)
#      26 # Gather results when done
# ---> 27 results = client.gather(futures)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/client.py:2566, in Client.gather(self, futures, errors, direct, asynchronous)
#    2563     local_worker = None
#    2565 with shorten_traceback():
# -> 2566     return self.sync(
#    2567         self._gather,
#    2568         futures,
#    2569         errors=errors,
#    2570         direct=direct,
#    2571         local_worker=local_worker,
#    2572         asynchronous=asynchronous,
#    2573     )
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# Process Dask Worker process (from Nanny):
# 2026-02-02 15:40:02,218 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt
# 2026-02-02 15:40:02,222 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/base_events.py", line 687, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/nanny.py", line 985, in run
#     await worker.finished()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/core.py", line 494, in finished
#     await self._event_finished.wait()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/locks.py", line 212, in wait
#     await fut
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/distributed/nanny.py", line 1023, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 194, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/asyncio/runners.py", line 123, in run
#     raise KeyboardInterrupt()
# KeyboardInterrupt

# %%
# Convert results (list of dicts) to a nice table
df_results = pd.DataFrame(results)

# Optional: reorder columns
df_results = df_results[["seed", "best_f", "best_x", "nfev"]]

# Display nicely
df_results

# %%
import pickle
from pathlib import Path

results_folder = Path("results_5")
result_files = list(results_folder.glob("result_seed_*.pkl"))

loaded_results = []
for f in result_files:
    with open(f, "rb") as file:
        res = pickle.load(file)
        loaded_results.append(res)

# Example: print best objective per seed
for r in loaded_results:
    print(f"Seed {r['seed']}: best_f = {r['best_f']}, nfev = {r['nfev']}")

# %%
best_params_list = []

for run_idx, run in enumerate(results):
    seed = run["seed"]
    history = run["history"]

    # find the best evaluation by objective value
    best_idx = np.argmin(history["objective"])

    best_theta_phys = history["theta_phys"][best_idx]
    best_obj = history["objective"][best_idx]
    best_nse = history["nse"][best_idx]
    best_kge = history["kge"][best_idx]
    best_vol_err = history["vol_err"][best_idx]

    row = {
        "seed": seed,
        "best_eval": best_idx + 1,
        "objective": best_obj,
        "nse": best_nse,
        "kge": best_kge,
        "vol_err": best_vol_err,
    }

    # add each parameter with its proper name
    for i, th in enumerate(best_theta_phys):
        row[parameter_names[i]] = th

    best_params_list.append(row)

# create DataFrame
best_params_df = pd.DataFrame(best_params_list)
best_params_df

# %%
import numpy as np
import pandas as pd

# Suppose you have multiple seeds in `results`:
dfs = []
for seed_idx, res_seed in enumerate(results):
    hist = res_seed["history"]
    df = pd.DataFrame(hist)
    df["seed"] = seed_idx  # add a seed column
    dfs.append(df)

history_df = pd.concat(dfs, ignore_index=True)

n_params = len(p_min)  # 9
seeds = history_df["seed"].unique()  # get all unique seeds
colors = plt.cm.tab10(np.linspace(0, 1, len(seeds)))  # assign colors

n_cols = 3
n_rows = int(np.ceil(n_params / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 3 * n_rows))
axes = axes.flatten()  # flatten for easy indexing

for i in range(n_params):
    ax = axes[i]

    for seed, color in zip(seeds, colors):
        theta_array = np.stack(history_df.loc[history_df["seed"] == seed, "theta_phys"].values)
        obj_array = history_df.loc[history_df["seed"] == seed, "objective"].values
        ax.scatter(theta_array[:, i], obj_array, label=f"Seed {seed}", color=color, alpha=0.3, s=10)
        ax.set_xlabel(parameter_names[i])

    ax.set_ylabel("Objective")
    # ax.set_title()
    ax.set_xlim(p_min[i], p_max[i])
    ax.grid(True)

# remove empty axes
for j in range(n_params, len(axes)):
    fig.delaxes(axes[j])


# axes[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Parameter columns
param_cols = ["Imax", "Ce", "Sumax", "Beta", "Pmax", "Tlag", "Kf", "Ks", "FM"]

# Scale the best parameters
scaled_params_df = pd.DataFrame(scale(best_params_df[param_cols].to_numpy()), columns=param_cols)


plt.figure(figsize=(12, 4))
# sns.boxplot(data=scaled_params_df, color = 'lightgray')
# sns.stripplot(data=scaled_params_df, color='black', jitter=False, size=8)
sns.boxplot(
    data=scaled_params_df, color="lightgray", fliersize=0
)  # light gray boxes, hide default outliers
sns.stripplot(data=scaled_params_df, color="black", jitter=True, size=6, marker="o")  # black dots

plt.xticks(rotation=45)
plt.ylabel("Scaled parameter value (0-1)")
plt.title("Scaled best parameter sets across seeds")
# add horizontal grid lines
plt.grid(axis="y", linestyle="--", alpha=0.5)

plt.show()

# %%
from dask.distributed import Client

# Assuming you created a client earlier
client.close()  # closes client and shuts down local cluster/workers
