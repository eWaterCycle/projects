# %%
# setup imports
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[2]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

# %%
import multiprocessing
import os

# Total CPUs available
print("os.cpu_count():", os.cpu_count())

# CPUs visible to Python multiprocessing
print("multiprocessing.cpu_count():", multiprocessing.cpu_count())
# Out:
# os.cpu_count(): 4
# multiprocessing.cpu_count(): 4

# %%
import psutil

psutil.cpu_count(logical=True), psutil.cpu_count(logical=False)
# Out:
# (4, 4)

# %%
# Out:
#         <iframe
#             width="1200"
#             height="600"
#             src="http://127.0.0.1:8787/status"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
