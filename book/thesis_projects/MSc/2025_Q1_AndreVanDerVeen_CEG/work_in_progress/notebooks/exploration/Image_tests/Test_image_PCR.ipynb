# %% [markdown]
# ## Image testing
#
# This notebook is for further testing of containers for pcrglobwb

# %%
from pathlib import Path

import ewatercycle.forcing
import ewatercycle.models
import ewatercycle.parameter_sets
from ewatercycle.container import ContainerImage

# %%
Chatly_station_latitude = 42.34332908492399 - 0.5  # Amu Darya near Chatly
Chatly_station_longitude = (
    59.627516175820965 + 0.9
)  # Through trial and error, to get modelled discharge closer to observed

Kerki_station_latitude = 37.8396310038444  # Amu Darya near Kerki
Kerki_station_longitude = 65.23703868931334

Tyumen_station_latitude = 44.05 - 0.1  # Syr Darya near Tyumen, through trial and error
Tyumen_station_longitude = 67.05

Kazalinsk_station_latitude = (45.739988222442456,)  # Syr Darya near Kazalinsk
Kazalinsk_station_longitude = 62.115993992559744

Dushanbe_station_latitude = 38.76042
Dushanbe_staion_longitude = 68.81458

# %%
pcr_glob_directory = Path("/data/shared/parameter-sets/pcrglobwb_global")  # GlobalOption uit .ini

prepared_PCRGlob_forcing = (
    Path(
        "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Test_Aral/forcing_0419"
    )
    / "AralSeaBasin"
    / "pcrglobwb"
    / "work/diagnostic/script"
)  ##MeteoOptions uit .ini

prepared_PCRGlob_forcing_CMIP = (
    Path(
        "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Comparison/forcing_CMIP_5570"
    )
    / "AralSeaBasin"
    / "CMIP6"
    / "historic"
    / "PCRGlobWB"
    / "work/diagnostic/script"
)  ##MeteoOptions uit .ini

# %%
parameter_set_cmip = ewatercycle.parameter_sets.ParameterSet(
    name="custom_parameter_set",
    directory=pcr_glob_directory,
    config="/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/_Comparison/Reference_05min_agri_copy.ini",
    target_model="pcrglobwb",
    supported_model_versions={"unknown"},
)


# parameter_set_cmip_no_agri = ewatercycle.parameter_sets.ParameterSet(
#     name="custom_parameter_set",
#     directory=pcr_glob_directory,
#     config= Path.cwd() / "Reference_05min_no_agri.ini",
#     target_model="pcrglobwb",
#     supported_model_versions={"fixed"},
# )

# %%
forcing = ewatercycle.forcing.sources["PCRGlobWBForcing"].load(
    directory=prepared_PCRGlob_forcing,
)


print(forcing)
# Out:
# start_time='2004-01-01T00:00:00Z' end_time='2019-12-31T00:00:00Z' directory=PosixPath('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Test_Aral/forcing_0419/AralSeaBasin/pcrglobwb/work/diagnostic/script') shape=PosixPath('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Test_Aral/forcing_0419/AralSeaBasin/pcrglobwb/work/diagnostic/script/AralSeaBasin.shp') filenames={} precipitationNC='pcrglobwb_OBS6_ERA5_reanaly_1_day_pr_2004-2019_AralSeaBasin.nc' temperatureNC='pcrglobwb_OBS6_ERA5_reanaly_1_day_tas_2004-2019_AralSeaBasin.nc'

# %%
my_image = ContainerImage("/home/avandervee3/ewatercycle-pcr-7dec.sif")
my_image.version
# Out:
# 'unknown'

# %%
reference = ewatercycle.models.PCRGlobWB(
    parameter_set=parameter_set_cmip, forcing=forcing, bmi_image=my_image
)

print(reference)
# Out:
# ---------------------------------------------------------------------------
# NoSectionError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 reference = ewatercycle.models.PCRGlobWB(
#       2     parameter_set=parameter_set_cmip,
#       3     forcing=forcing,
#       4     bmi_image=my_image
#       5 )
#       7 print(reference)
#
#     [... skipping hidden 1 frame]
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle_pcrglobwb/model.py:61, in PCRGlobWB._initialize_config(self)
#      59 cfg = CaseConfigParser()
#      60 cfg.read(self.parameter_set.config)
# ---> 61 cfg.set("globalOptions", "inputDir", str(self.parameter_set.directory))
#      63 if self.forcing:
#      64     assert self.forcing.temperatureNC is not None  # TODO fix forcing class.
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/configparser.py:1184, in ConfigParser.set(self, section, option, value)
#    1181 """Set an option.  Extends RawConfigParser.set by validating type and
#    1182 interpolation syntax on the value."""
#    1183 self._validate_value_types(option=option, value=value)
# -> 1184 super().set(section, option, value)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/configparser.py:880, in RawConfigParser.set(self, section, option, value)
#     878         sectdict = self._sections[section]
#     879     except KeyError:
# --> 880         raise NoSectionError(section) from None
#     881 sectdict[self.optionxform(option)] = value
#
# NoSectionError: No section: 'globalOptions'
