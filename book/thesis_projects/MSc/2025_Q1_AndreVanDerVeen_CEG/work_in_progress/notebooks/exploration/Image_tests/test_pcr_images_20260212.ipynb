# %% [markdown]
# ## Testing docker images
#
# * troubleshot docker images
# * bmi-model implementation
# * bmi-plugin implementation
#
# current date: 2026-02-12
#
# made some progress, swap_xy from plugin causing some troubles

# %%
# docker build -t ewatercycle-pcr-12feb .
# docker save -o ewatercycle_pcr_12feb.tar ewatercycle-pcr-12feb
# apptainer build ewatercycle_pcr_12feb.sif docker-archive://ewatercycle_pcr_12feb.tar

# %%
import sys
from pathlib import Path

import ewatercycle.forcing
import ewatercycle.models
import ewatercycle.parameter_sets
from ewatercycle.container import ContainerImage
from rich import print

PROJECT_ROOT = Path().resolve().parents[2]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

from datetime import datetime

import pandas as pd
from tqdm.notebook import tqdm

from src.constants import STATIONS_PCR
from src.paths import FORCING_PCRGLOB, INI_FILES, LOAD_PCR, PCR_GLOBAL_PARAMS, PCR_TAIL
# Out:
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498

# %%
STATIONS_PCR
# Out:
# {'Chatly': {'lat': 42.2, 'lon': 60.2},
#  'Kazalinsk': {'lat': 45.7, 'lon': 62.12},
#  'Kerki': {'lat': 37.83, 'lon': 65.25},
#  'Tyumen-Aryk': {'lat': 43.95, 'lon': 67.05},
#  'Karaozek': {'lat': 44.95, 'lon': 65.27}}

# %%
pcr_glob_directory = PCR_GLOBAL_PARAMS  # GlobalOption uit .ini
prepared_pcr_forcing = FORCING_PCRGLOB / LOAD_PCR / PCR_TAIL


parameter_set_test = ewatercycle.parameter_sets.ParameterSet(
    name="custom_parameter_set",
    directory=pcr_glob_directory,
    config=INI_FILES / "test_container_images.ini",
    target_model="pcrglobwb",
    supported_model_versions={"12feb"},
)

forcing = ewatercycle.forcing.sources["PCRGlobWBForcing"].load(
    directory=prepared_pcr_forcing,
)

# %%
my_image = ContainerImage("/home/avandervee3/ewatercycle_pcr_12feb.sif")
my_image.version
# Out:
# '12feb'

# %%
reference = ewatercycle.models.PCRGlobWB(
    parameter_set=parameter_set_test, forcing=forcing, bmi_image=my_image
)


print(reference)
# Out:
# PCRGlobWB(
#     parameter_set=ParameterSet(
#         name='custom_parameter_set',
#         directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_global'),
#         config=PosixPath('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_i
# n_progress/model_runs/pcrglobwb/ini_files/test_container_images.ini'),
#         doi='N/A',
#         target_model='pcrglobwb',
#         supported_model_versions={'12feb'},
#         downloader=None
#     ),
#     forcing=PCRGlobWBForcing(
#         start_time='1940-01-01T00:00:00Z',
#         end_time='1960-12-31T00:00:00Z',
#         directory=PosixPath('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/wor
# k_in_progress/forcing/output/PCRGLOBWB/ERA5_1940-1960/AralSea_basin/work/diagnostic/script'),
#         shape=PosixPath('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in
# _progress/forcing/output/PCRGLOBWB/ERA5_1940-1960/AralSea_basin/work/diagnostic/script/AralSea_basin.shp'),
#         filenames={},
#         precipitationNC='pcrglobwb_OBS6_ERA5_reanaly_1_day_pr_1940-1960_AralSea_basin.nc',
#         temperatureNC='pcrglobwb_OBS6_ERA5_reanaly_1_day_tas_1940-1960_AralSea_basin.nc'
#     )
# )

# %%
experiment_start_date = "1950-01-01T00:00:00Z"
experiment_end_date = "1950-01-31T00:00:00Z"

# %%
reference_config, reference_dir = reference.setup(
    start_time=experiment_start_date, end_time=experiment_end_date, max_spinups_in_years=0
)
reference_config, reference_dir
# Out:
# ('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/notebooks/exploration/Image_tests/pcrglobwb_20260212_154811/pcrglobwb_ewatercycle.ini',
#  '/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/notebooks/exploration/Image_tests/pcrglobwb_20260212_154811')

# %%
print(reference.parameters)

refence_para = reference.parameters

# Convert ISO 8601 strings to datetime objects
start_time = datetime.strptime(experiment_start_date, "%Y-%m-%dT%H:%M:%SZ")
end_time = datetime.strptime(experiment_end_date, "%Y-%m-%dT%H:%M:%SZ")

# Calculate the number of days for the progression bar
delta = end_time - start_time
number_of_days = delta.days
print(f"Number of days to model: {number_of_days}")
# Out:
# dict_items([('start_time', '1950-01-01T00:00:00Z'), ('end_time', '1950-01-31T00:00:00Z'), ('routing_method',
# 'accuTravelTime'), ('max_spinups_in_years', '0')])
# Number of days to model: 30

# %%
print("Using config:", reference_config)
# Out:
# Using config:
# /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/notebooks/explo
# ration/Image_tests/pcrglobwb_20260212_154811/pcrglobwb_ewatercycle.ini

# %%
reference.initialize(reference_config)

# %%
time = pd.date_range(reference.start_time_as_isostr, reference.end_time_as_isostr)
stations_timeseries = pd.DataFrame(
    index=pd.Index(time, name="time"), columns=["Chatly", "Kerki", "Tyumen", "Kazalinsk"]
)
stations_timeseries.head()


stations_timeseries_reference = stations_timeseries.copy()

# %%
for _ in tqdm(range(number_of_days), desc="Running model"):
    reference.update()

print("Model run finished!")
# Out:
# Running model:   0%|          | 0/30 [00:00<?, ?it/s]
# Model run finished!

# %%
reference.finalize()

# %% [markdown]
# ## test get value
#
# bmi implementation

# %%
test_get_value = ewatercycle.models.PCRGlobWB(
    parameter_set=parameter_set_test, forcing=forcing, bmi_image=my_image
)

# %%
test_get_value_config, test_get_value_dir = test_get_value.setup(
    start_time=experiment_start_date, end_time=experiment_end_date, max_spinups_in_years=0
)
test_get_value_config, test_get_value_dir
# Out:
# ('/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/notebooks/exploration/Image_tests/pcrglobwb_20260212_155140/pcrglobwb_ewatercycle.ini',
#  '/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/notebooks/exploration/Image_tests/pcrglobwb_20260212_155140')

# %%
test_get_value.initialize(test_get_value_config)

# %%
for _ in tqdm(range(number_of_days), desc="Running model"):
    test_get_value.update()

    # Track discharge at station locations
    discharge_at_Chatly = test_get_value.get_value_at_coords(
        "discharge",
        lat=STATIONS_PCR["Chatly"]["lat"],
        lon=STATIONS_PCR["Chatly"]["lon"],
    )

    test_values = test_get_value.get_value("top_layer_soil_saturation")

    #     discharge_at_station = test_get_value.get_value_at_coords(
    #     "discharge",
    #     lat=[lat],
    #     lon=[lon]
    # )

    # time = reference.time_as_isostr
    stations_timeseries.loc[time, "Chatly"] = discharge_at_Chatly[0]

print(type(test_values))
print("Model run finished!")

print(type(discharge_at_Chatly))
# Out:
# Running model:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py:343, in BmiClient.get_grid_x(self, grid, x)
#     342 try:
# --> 343     src = numpy.array(self.stub.getGridX(bmi_pb2.GridRequest(grid_id=grid)).coordinates)
#     344     numpy.copyto(src=src, dst=x)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py:1176, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1170 (
#    1171     state,
#    1172     call,
#    1173 ) = self._blocking(
#    1174     request, timeout, metadata, credentials, wait_for_ready, compression
#    1175 )
# -> 1176 return _end_unary_response_blocking(state, call, False, None)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py:1005, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1004 else:
# -> 1005     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.INTERNAL
# 	details = "if you see this swap XY happend"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2026-02-12T16:52:48.93959199+01:00", grpc_status:13, grpc_message:"if you see this swap XY happend"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# RemoteException                           Traceback (most recent call last)
# Cell In[18], line 6
#       3     test_get_value.update()
#       5     # Track discharge at station locations
# ----> 6     discharge_at_Chatly = test_get_value.get_value_at_coords(
#       7         "discharge",
#       8         lat = STATIONS_PCR["Chatly"]["lat"],
#       9         lon = STATIONS_PCR["Chatly"]["lon"],
#      10
#      11     )
#      13     test_values = test_get_value.get_value("top_layer_soil_saturation")
#      15 #     discharge_at_station = test_get_value.get_value_at_coords(
#      16 #     "discharge",
#      17 #     lat=[lat],
#    (...)
#      20
#      21     #time = reference.time_as_isostr
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle_pcrglobwb/model.py:216, in PCRGlobWB.get_value_at_coords(self, name, lat, lon)
#     206 def get_value_at_coords(
#     207     self, name, lat: Iterable[float], lon: Iterable[float]
#     208 ) -> np.ndarray:
#     209     """Get a copy of values of the given variable at lat/lon coordinates.
#     210
#     211     Args:
#    (...)
#     214         lon: Longitudinal value
#     215     """
# --> 216     indices = self._coords_to_indices(name, lat, lon)
#     217     indices = np.array(indices)
#     218     return self.get_value_at_indices(name, indices)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/model.py:240, in eWaterCycleModel._coords_to_indices(self, name, lat, lon)
#     230 def _coords_to_indices(
#     231     self, name: str, lat: Iterable[float], lon: Iterable[float]
#     232 ) -> Iterable[int]:
#     233     """Convert lat/lon values to index.
#     234
#     235     Args:
#    (...)
#     238         lon: Longitudinal value
#     239     """
# --> 240     grid_lat, grid_lon, shape = self.get_latlon_grid(name)
#     242     indices = []
#     243     for point_lon, point_lat in zip(lon, lat, strict=False):
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle_pcrglobwb/model.py:203, in PCRGlobWB.get_latlon_grid(self, name)
#     201 shape = self._bmi.get_grid_shape(grid_id)
#     202 grid_lon = self._bmi.get_grid_x(grid_id, np.zeros(shape[1]))
# --> 203 grid_lat = self._bmi.get_grid_y(grid_id, np.zeros(shape[0]))
#     204 return grid_lat, grid_lon, shape
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_optionaldest.py:153, in OptionalDestBmi.get_grid_y(self, grid, y)
#     151 if y is None:
#     152     y = reserve_grid_nodes(self.origin, grid, 1)
# --> 153 return self.origin.get_grid_y(grid, y)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_memoized.py:140, in MemoizedBmi.get_grid_y(self, grid, y)
#     139 def get_grid_y(self, grid, y):
# --> 140     y[:] = self._cache('get_grid_y', grid, y)
#     141     return y
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_memoized.py:52, in MemoizedBmi._cache(self, fn, arg, output)
#      50             self.cache[fn][arg] = getattr(self.origin, fn)(arg)
#      51         else:
# ---> 52             self.cache[fn][arg] = getattr(self.origin, fn)(arg, output)
#      53 return self.cache[fn][arg]
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle_pcrglobwb/model.py:37, in _SwapXY.get_grid_y(self, grid, y)
#      36 def get_grid_y(self, grid: int, y: np.ndarray) -> np.ndarray:
# ---> 37     return self.origin.get_grid_x(grid, y)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py:347, in BmiClient.get_grid_x(self, grid, x)
#     345     return x
#     346 except grpc.RpcError as e:
# --> 347     handle_error(e)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py:46, in handle_error(exc)
#      44         remote_traceback = info.stack_entries
#      45         remote_detail = info.detail
# ---> 46         raise RemoteException(remote_detail, remote_traceback) from exc
#      47 raise
#
# RemoteException: NotImplementedError('if you see this swap XY happend')

# %%
test_get_value.finalize()
