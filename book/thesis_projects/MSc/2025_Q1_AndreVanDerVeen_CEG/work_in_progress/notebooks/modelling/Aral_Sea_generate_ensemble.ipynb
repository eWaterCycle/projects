# %% [markdown]
# ## makes the river discharge forcing for aral sea model

# %%
# setup imports
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[1]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))


from src.constants import DUMMY_HBV_INITIAL
from src.forcing import generate_lumped_CMIP_historical_forcing
from src.models import run_hbv_for_best_params
from src.paths import *
# Out:
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498

# %%
### generate forcing
experiment_start_date = "1940-01-01T00:00:00Z"
experiment_end_date = "2014-12-31T00:00:00Z"

shapefile_kerki = "Kerki_GRDC"
shapefile_TA = "Tyumen_Aryk_GRDC"
shapefile_Aral = "AralSea"
shapefile_chatly = "Chatly_GRDC"

# ERA5_forcing_kerki = generate_lumped_ERA5_forcing(shapefile_kerki, experiment_start_date, experiment_end_date)
# ERA5_forcing_TA = generate_lumped_ERA5_forcing(shapefile_TA, experiment_start_date, experiment_end_date)
# ERA5_forcing_Aral = generate_lumped_ERA5_forcing(shapefile_Aral, experiment_start_date, experiment_end_date)
# ERA5_forcing_chatly = generate_lumped_ERA5_forcing(shapefile_chatly, experiment_start_date, experiment_end_date)

ERA5_forcing_kerki = generate_lumped_CMIP_historical_forcing(
    shapefile_kerki, experiment_start_date, experiment_end_date
)
ERA5_forcing_TA = generate_lumped_CMIP_historical_forcing(
    shapefile_TA, experiment_start_date, experiment_end_date
)
ERA5_forcing_Aral = generate_lumped_CMIP_historical_forcing(
    shapefile_Aral, experiment_start_date, experiment_end_date
)
ERA5_forcing_chatly = generate_lumped_CMIP_historical_forcing(
    shapefile_chatly, experiment_start_date, experiment_end_date
)

# %%
path_to_chatly_params = RUNS_HBV / "cmaes_dask_Chatly" / "best_params_df_chatly.pkl"


results_chatly = run_hbv_for_best_params(
    shapefile=shapefile_chatly,
    forcing_type="CMIP_HIST",
    year_span="1940-2014",
    params_path=path_to_chatly_params,
    initial_conditions=DUMMY_HBV_INITIAL,
)
# Out:
# ...
# Running HBV model:   0%|          | 0/27393 [00:00<?, ?it/s]

# %%
path_to_kerki_params = RUNS_HBV / "cmaes_dask_test" / "best_params_df_kerki.pkl"


results_kerki = run_hbv_for_best_params(
    shapefile=shapefile_kerki,
    forcing_type="CMIP_HIST",
    year_span="1940-2014",
    params_path=path_to_kerki_params,
    initial_conditions=DUMMY_HBV_INITIAL,
)
# Out:
# ...
# Running HBV model:   0%|          | 0/27393 [00:00<?, ?it/s]

# %%
path_to_TA_params = RUNS_HBV / "cmaes_dask_TA" / "best_params_df_TA.pkl"


results_kerki = run_hbv_for_best_params(
    shapefile=shapefile_TA,
    forcing_type="CMIP_HIST",
    year_span="1940-2014",
    params_path=path_to_TA_params,
    initial_conditions=DUMMY_HBV_INITIAL,
)
# Out:
# ...
# Running HBV model:   0%|          | 0/27393 [00:00<?, ?it/s]
