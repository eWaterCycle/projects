# %% [markdown]
# ## test making .tex table of grdc data

# %%
# setup imports
import sys
from pathlib import Path


PROJECT_ROOT = Path().resolve().parents[2]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

from src.paths import *
from src.utils import build_grdc_metadata_table

# %%
path_to_grdc=GRDC/"Combined"
print(path_to_grdc)
# Out:
# /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/data/grdc/Combined

# %%
df = build_grdc_metadata_table(
    folder_path=path_to_grdc,
    export_dir=TABLES,
)
# Out:
# /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/utils.py:329: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return df.applymap(_sanitize_latex)

# %%
print(df)
# Out:
#     GRDC No.      Station Lat (°N) Lon (°E)  Catchment (km²)  \
# 0    2217100  KULUKH TEPA    36.98    68.30            37100
# 1    2217100  KULUKH TEPA    36.98    68.30            37100
# 2    2217101    CHAR DARA    36.70    68.83            24820
# 3    2217102      BAGHLAN    36.10    68.67            19740
# 4    2217102      BAGHLAN    36.10    68.67            19740
# ..       ...          ...      ...      ...              ...
# 163  2817420     KATTAGAN    38.99    67.07              435
# 164  2817410   KING GUZAR    38.43    67.88              901
# 165  2817460   KHAZARNOVA    39.02    67.17              845
# 167  2817630    OBIZARANG    38.33    68.00             2630
# 169  2817635      ZARCHOB    38.27    67.90             2200
#
#            Time Series Data Lines     Freq
# 0    1965-10 - 1978-09      4,748    Daily
# 1          1965 - 1978        156  Monthly
# 2    1964-08 - 1978-09      5,170    Daily
# 3    1968-04 - 1978-09      3,829    Daily
# ...

# %%
df.head(10)
# Out:
#   GRDC No.           Station Lat (°N) Lon (°E)  Catchment (km²)  \
# 0  2217100       KULUKH TEPA    36.98    68.30            37100
# 1  2217100       KULUKH TEPA    36.98    68.30            37100
# 2  2217101         CHAR DARA    36.70    68.83            24820
# 3  2217102           BAGHLAN    36.10    68.67            19740
# 4  2217102           BAGHLAN    36.10    68.67            19740
# 5  2217101         CHAR DARA    36.70    68.83            24820
# 6  2217103  PUL-I-KONDA SANG    35.60    68.60            12610
# 7  2217103  PUL-I-KONDA SANG    35.60    68.60            12610
# 8  2217104     DASHT-I-SAFED    35.30    67.92             3795
# 9  2217104     DASHT-I-SAFED    35.30    67.92             3795
#
#          Time Series Data Lines     Freq
# 0  1965-10 - 1978-09      4,748    Daily
# 1        1965 - 1978        156  Monthly
# 2  1964-08 - 1978-09      5,170    Daily
# 3  1968-04 - 1978-09      3,829    Daily
# 4        1968 - 1978        126  Monthly
# ...
