# %% [markdown]
# # Template for plotting PCR forcing data for visual inspection

# %%
import xarray as xr

# %%
filename_tas = "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/forcing/output/PCRGLOBWB/ERA5_1940-1940/AralSea_basin/work/diagnostic/script/pcrglobwb_OBS6_ERA5_reanaly_1_day_tas_1940-1940_AralSea_basin.nc"
filename_pr = "/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/forcing/output/PCRGLOBWB/ERA5_1940-1940/AralSea_basin/work/diagnostic/script/pcrglobwb_OBS6_ERA5_reanaly_1_day_pr_1940-1940_AralSea_basin.nc"

# %%
# open the file
ds_tas = xr.open_dataset(filename_tas)
ds_pr = xr.open_dataset(filename_pr)


# quick plot
ds_tas["tas"].isel(time=-1).plot(cmap="coolwarm")

# %%
# quick plot
ds_pr["pr"].isel(time=-1).plot(cmap="coolwarm", robust=True, size=5)
