# %% [markdown]
# # Get metadata on available ESGF (CMIP6) datasets and store in json files
# In this notebook ```ESMValTool``` is used to query available ESGF nodes to find which available climate model runs contain the variables we are interested in. Using a template dictionary we find all available datasets that contain variables from a list of variables and match the template. For each ```dataset``` (for example 'EC-Earth3') we create a json file that holds the meta-info on all ensemble members that match the criteria from the template. These json files can later be used to generate forcing
#
# We use this here to get meta-info for a specific CMIP6 scenarion (in our case: ssp585) so we can later build forcing input for hydrological models in eWaterCycle.
#
# ## Note on names
# Confusingly, names like ```dataset``` and not uniquely defined. A ```Dataset``` object in EMSValTool is a combination of climate model, ensemble member, experiment, etc. However, the 'climate model' in a ```Dataset``` is identified using the key ```dataset```. This is confusing, but outside of my control.
#
# ## Note on downloaded data
# This notebook only queries for meta-data and does not download any other data. It will generate, however, quite some json files that are stored in the configFiles directory
#
# ## Note on eWaterCycle vs ESMValTool
# In this notebook we use none of the core eWaterCycle package functions. The function to query ESGF is from ESMValTool and there is no eWaterCycle wrapper around ESMValTool for this specific use case.

# %%
import ewatercycle.esmvaltool.search
from esmvalcore.config import CFG

from rich import print
import json

# %%
# Setting for ESMValTool to make sure the online esgf resources are always used and
# we don't rely on locally cached information.
CFG['search_esgf'] = 'always'

# %%
experiment=["historical","ssp245","ssp585"],
project = "CMIP6",
frequency="day",
variables=["pr", "tas", "rsds"]

# %%
# We query the ESGF databases for available datasets. This calls external servers that host ESGF
# metadata which may be down at any moment. This query can take a long time to complete (minutes 
# to half an hour easily)



# valid_datasets = ewatercycle.esmvaltool.search.search_esgf(
#     experiment=["historical","ssp126","ssp245","ssp370","ssp585"],
#     project = "CMIP6",
#     frequency="day",
#     variables=["pr", "tas", "rsds"]
# ),

# %%
# print(valid_datasets)

# %%
# # Convert sets to lists for JSON serialization
# serializable_valid_datasets = {key: list(value) for key, value in valid_datasets[0].items()}
# #
# # # Write to a JSON file
# with open("available_climate_datasets.json", "w") as json_file:
#     json.dump(serializable_valid_datasets, json_file, indent=4)

# %%
# Read from the JSON file
with open("available_climate_datasets.json", "r") as json_file:
    loaded_dict = json.load(json_file)

# Convert lists back to sets
restored_valid_datasets = {key: set(value) for key, value in loaded_dict.items()}

print("Restored dictionary:", restored_valid_datasets)
# Out:
# Restored dictionary:
# {
#     'CNRM-CM6-1-HR': {'r1i1p1f2'},
#     'AWI-ESM-1-1-LR': {'r1i1p1f1'},
#     'KIOST-ESM': {'r1i1p1f1'},
#     'MPI-ESM1-2-HR': {
#         'r2i1p1f1',
#         'r1i1p1f1',
#         'r9i1p1f1',
#         'r10i1p1f1',
#         'r4i1p1f1',
#         'r8i1p1f1',
#         'r7i1p1f1',
#         'r6i1p1f1',
#         'r3i1p1f1',
#         'r5i1p1f1'
#     },
#     'KACE-1-0-G': {'r3i1p1f1', 'r2i1p1f1', 'r1i1p1f1'},
#     'IPSL-CM6A-LR': {
#         'r20i1p1f1',
#         'r21i1p1f1',
#         'r30i1p1f1',
#         'r24i1p1f1',
#         'r28i1p1f1',
#         'r8i1p1f1',
#         'r31i1p1f1',
#         'r5i1p1f1',
#         'r22i1p1f1',
#         'r19i1p1f1',
#         'r29i1p1f1',
#         'r16i1p1f1',
#         'r25i1p1f1',
#         'r1i1p1f1',
#         'r9i1p1f1',
#         'r4i1p1f1',
#         'r15i1p1f1',
#         'r3i1p1f1',
#         'r11i1p1f1',
#         'r32i1p1f1',
#         'r2i1p1f1',
#         'r33i1p1f1',
#         'r6i1p1f1',
#         'r23i1p1f1',
#         'r18i1p1f1',
#         'r27i1p1f1',
#         'r26i1p1f1',
#         'r12i1p1f1',
#         'r10i1p1f1',
#         'r7i1p1f1',
#         'r14i1p1f1',
#         'r13i1p1f1',
#         'r17i1p1f1'
#     },
#     'AWI-CM-1-1-MR': {'r2i1p1f1', 'r1i1p1f1', 'r4i1p1f1', 'r3i1p1f1', 'r5i1p1f1'},
#     'IITM-ESM': {'r1i1p1f1'},
#     'CESM2-WACCM': {'r3i1p1f1', 'r2i1p1f1', 'r1i1p1f1'},
#     'NESM3': {'r2i1p1f1', 'r1i1p1f1'},
#     'BCC-CSM2-MR': {'r1i1p1f1'},
#     'ACCESS-ESM1-5': {'r3i1p1f1', 'r2i1p1f1', 'r1i1p1f1'},
#     'FGOALS-f3-L': {'r1i1p1f1'},
#     'FGOALS-g3': {'r1i1p1f1'},
#     'HadGEM3-GC31-LL': {
#         'r57i1p1f3',
#         'r21i1p1f3',
#         'r2i1p1f3',
#         'r42i1p1f3',
#         'r5i1p1f3',
#         'r24i1p1f3',
#         'r56i1p1f3',
#         'r39i1p1f3',
#         'r55i1p1f3',
#         'r32i1p1f3',
#         'r29i1p1f3',
#         'r40i1p1f3',
#         'r52i1p1f3',
#         'r35i1p1f3',
#         'r45i1p1f3',
#         'r50i1p1f3',
#         'r54i1p1f3',
#         'r34i1p1f3',
#         'r36i1p1f3',
#         'r31i1p1f3',
#         'r46i1p1f3',
#         'r58i1p1f3',
#         'r12i1p1f3',
#         'r17i1p1f3',
#         'r30i1p1f3',
#         'r47i1p1f3',
#         'r48i1p1f3',
#         'r26i1p1f3',
#         'r19i1p1f3',
#         'r20i1p1f3',
#         'r60i1p1f3',
#         'r15i1p1f3',
#         'r33i1p1f3',
#         'r38i1p1f3',
#         'r18i1p1f3',
#         'r28i1p1f3',
#         'r51i1p1f3',
#         'r43i1p1f3',
#         'r11i1p1f3',
#         'r25i1p1f3',
#         'r49i1p1f3',
#         'r1i1p1f3',
#         'r22i1p1f3',
#         'r14i1p1f3',
#         'r4i1p1f3',
#         'r16i1p1f3',
#         'r44i1p1f3',
#         'r13i1p1f3',
#         'r53i1p1f3',
#         'r27i1p1f3',
#         'r23i1p1f3',
#         'r37i1p1f3',
#         'r3i1p1f3',
#         'r41i1p1f3',
#         'r59i1p1f3'
#     },
#     'EC-Earth3-CC': {'r1i1p1f1'},
#     'CMCC-ESM2': {'r1i1p1f1'},
#     'ACCESS-CM2': {'r1i1p1f1'},
#     'TaiESM1': {'r1i1p1f1'},
#     'INM-CM5-0': {
#         'r2i1p1f1',
#         'r1i1p1f1',
#         'r9i1p1f1',
#         'r10i1p1f1',
#         'r4i1p1f1',
#         'r8i1p1f1',
#         'r7i1p1f1',
#         'r6i1p1f1',
#         'r3i1p1f1',
#         'r5i1p1f1'
#     },
#     'IPSL-CM5A2-INCA': {'r1i1p1f1'},
#     'CESM2-WACCM-FV2': {'r1i1p1f1'},
#     'CNRM-CM6-1': {
#         'r23i1p1f2',
#         'r3i1p1f2',
#         'r24i1p1f2',
#         'r20i1p1f2',
#         'r2i1p1f2',
#         'r19i1p1f2',
#         'r12i1p1f2',
#         'r8i1p1f2',
#         'r18i1p1f2',
#         'r1i1p1f2',
#         'r5i1p1f2',
#         'r26i1p1f2',
#         'r30i1p1f2',
#         'r14i1p1f2',
#         'r13i1p1f2',
#         'r17i1p1f2',
#         'r22i1p1f2',
#         'r7i1p1f2',
#         'r21i1p1f2',
#         'r16i1p1f2',
#         'r29i1p1f2',
#         'r28i1p1f2',
#         'r11i1p1f2',
#         'r9i1p1f2',
#         'r10i1p1f2',
#         'r27i1p1f2',
#         'r4i1p1f2',
#         'r15i1p1f2',
#         'r25i1p1f2',
#         'r6i1p1f2'
#     },
#     'EC-Earth3-Veg-LR': {'r1i1p1f1'},
#     'NorESM2-LM': {'r3i1p1f1', 'r2i1p1f1', 'r1i1p1f1'},
#     'NorESM2-MM': {'r1i1p1f1'},
#     'CMCC-CM2-SR5': {
#         'r6i1p2f1',
#         'r9i1p2f1',
#         'r2i1p2f1',
#         'r4i1p2f1',
#         'r11i1p2f1',
#         'r3i1p2f1',
#         'r7i1p2f1',
#         'r1i1p1f1',
#         'r10i1p2f1',
#         'r8i1p2f1',
#         'r5i1p2f1'
#     },
#     'UKESM1-0-LL': {
#         'r3i1p1f2',
#         'r5i1p1f3',
#         'r2i1p1f2',
#         'r19i1p1f2',
#         'r12i1p1f2',
#         'r8i1p1f2',
#         'r18i1p1f2',
#         'r1i1p1f2',
#         'r5i1p1f2',
#         'r14i1p1f2',
#         'r13i1p1f2',
#         'r17i1p1f2',
#         'r7i1p1f2',
#         'r6i1p1f3',
#         'r16i1p1f2',
#         'r11i1p1f2',
#         'r7i1p1f3',
#         'r9i1p1f2',
#         'r10i1p1f2',
#         'r4i1p1f2',
#         'r15i1p1f2',
#         'r6i1p1f2'
#     },
#     'ICON-ESM-LR': {'r2i1p1f1', 'r1i1p1f1', 'r4i1p1f1', 'r3i1p1f1', 'r5i1p1f1'},
#     'CNRM-ESM2-1': {
#         'r8i1p1f2',
#         'r11i1p1f2',
#         'r13i1p1f2',
#         'r3i1p1f2',
#         'r9i1p1f2',
#         'r1i1p1f2',
#         'r7i1p1f2',
#         'r5i1p1f2',
#         'r10i1p1f2',
#         'r2i1p1f2',
#         'r4i1p1f2',
#         'r15i1p1f2',
#         'r14i1p1f2',
#         'r12i1p1f2',
#         'r6i1p1f2'
#     },
#     'AWI-ESM-1-REcoM': {'r1i1p1f1'},
#     'BCC-ESM1': {'r3i1p1f1', 'r2i1p1f1', 'r1i1p1f1'},
#     'CMCC-CM2-HR4': {'r1i1p1f1'},
#     'MRI-ESM2-0': {'r2i1p1f1', 'r1i2p1f1', 'r1i1p1f1', 'r4i1p1f1', 'r3i1p1f1', 'r5i1p1f1'},
#     'CESM2': {
#         'r2i1p1f1',
#         'r1i1p1f1',
#         'r9i1p1f1',
#         'r10i1p1f1',
#         'r4i1p1f1',
#         'r8i1p1f1',
#         'r7i1p1f1',
#         'r6i1p1f1',
#         'r3i1p1f1',
#         'r5i1p1f1'
#     },
#     'GFDL-CM4': {'r1i1p1f1'},
#     'INM-CM4-8': {'r1i1p1f1'},
#     'MPI-ESM-1-2-HAM': {'r3i1p1f1', 'r2i1p1f1', 'r1i1p1f1'},
#     'SAM0-UNICON': {'r1i1p1f1'},
#     'NorCPM1': {'r1i1p1f1'},
#     'EC-Earth3-AerChem': {'r1i1p1f1'},
#     'GFDL-ESM4': {'r1i1p1f1'},
#     'CAMS-CSM1-0': {'r2i1p1f1'},
#     'EC-Earth3': {'r2i1p1f1', 'r1i1p1f1', 'r9i1p1f1', 'r6i1p1f1', 'r13i1p1f1', 'r15i1p1f1', 'r11i1p1f1'},
#     'CESM2-FV2': {'r1i1p1f1'},
#     'CanESM5': {
#         'r20i1p1f1',
#         'r11i1p2f1',
#         'r21i1p1f1',
#         'r18i1p2f1',
#         'r24i1p1f1',
#         'r3i1p2f1',
#         'r8i1p1f1',
#         'r13i1p2f1',
#         'r10i1p2f1',
#         'r5i1p1f1',
#         'r22i1p1f1',
#         'r19i1p1f1',
#         'r12i1p2f1',
#         'r24i1p2f1',
#         'r9i1p2f1',
#         'r16i1p1f1',
#         'r2i1p2f1',
#         'r25i1p1f1',
#         'r22i1p2f1',
#         'r1i1p1f1',
#         'r16i1p2f1',
#         'r9i1p1f1',
#         'r4i1p1f1',
#         'r15i1p2f1',
#         'r17i1p2f1',
#         'r8i1p2f1',
#         'r19i1p2f1',
#         'r25i1p2f1',
#         'r11i1p1f1',
#         'r15i1p1f1',
#         'r3i1p1f1',
#         'r1i1p2f1',
#         'r4i1p2f1',
#         'r2i1p1f1',
#         'r6i1p1f1',
#         'r20i1p2f1',
#         'r23i1p1f1',
#         'r5i1p2f1',
#         'r18i1p1f1',
#         'r6i1p2f1',
#         'r7i1p2f1',
#         'r12i1p1f1',
#         'r10i1p1f1',
#         'r7i1p1f1',
#         'r14i1p1f1',
#         'r23i1p2f1',
#         'r13i1p1f1',
#         'r14i1p2f1',
#         'r17i1p1f1',
#         'r21i1p2f1'
#     },
#     'MIROC6': {'r3i1p1f1', 'r2i1p1f1', 'r1i1p1f1'},
#     'HadGEM3-GC31-MM': {'r4i1p1f3', 'r1i1p1f3', 'r3i1p1f3', 'r2i1p1f3'},
#     'MPI-ESM1-2-LR': {
#         'r20i1p1f1',
#         'r21i1p1f1',
#         'r30i1p1f1',
#         'r24i1p1f1',
#         'r47i1p1f1',
#         'r28i1p1f1',
#         'r8i1p1f1',
#         'r39i1p1f1',
#         'r31i1p1f1',
#         'r1i2000p1f1',
#         'r36i1p1f1',
#         'r34i1p1f1',
#         'r5i1p1f1',
#         'r22i1p1f1',
#         'r19i1p1f1',
#         'r46i1p1f1',
#         'r29i1p1f1',
#         'r42i1p1f1',
#         'r16i1p1f1',
#         'r41i1p1f1',
#         'r13i1p1f1',
#         'r25i1p1f1',
#         'r1i1p1f1',
#         'r9i1p1f1',
#         'r4i1p1f1',
#         'r40i1p1f1',
#         'r15i1p1f1',
#         'r37i1p1f1',
#         'r3i1p1f1',
#         'r11i1p1f1',
#         'r32i1p1f1',
#         'r2i1p1f1',
#         'r43i1p1f1',
#         'r33i1p1f1',
#         'r6i1p1f1',
#         'r49i1p1f1',
#         'r35i1p1f1',
#         'r23i1p1f1',
#         'r45i1p1f1',
#         'r18i1p1f1',
#         'r50i1p1f1',
#         'r27i1p1f1',
#         'r26i1p1f1',
#         'r12i1p1f1',
#         'r10i1p1f1',
#         'r7i1p1f1',
#         'r14i1p1f1',
#         'r44i1p1f1',
#         'r48i1p1f1',
#         'r38i1p1f1',
#         'r17i1p1f1'
#     },
#     'EC-Earth3-Veg': {'r14i1p1f1', 'r12i1p1f1'}
# }
